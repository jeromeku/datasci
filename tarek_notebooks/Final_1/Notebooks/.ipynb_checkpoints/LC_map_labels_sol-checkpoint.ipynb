# %% [markdown]
# # Import Necessary Packages and Modules

# %%
# %matplotlib inline

from __future__ import print_function



import matplotlib.pyplot as plt

from sklearn.cross_validation import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer


from sklearn.metrics import classification_report
from sklearn.svm import LinearSVC

import numpy as np
import pandas as pd


from IPython.display import Image
from wordcloud import WordCloud

# %% [markdown]
# # Load Live Community Questions

# %%
posts_table = pd.read_csv('../data/ml_posts_1.csv')
tags = posts_table[['cached_question_tag_list']]
tags = np.array(tags).ravel()
unique_tags = set(tags)

tag_labels_dict={}
tag_names=[]

for tag_id, some_tag in enumerate(unique_tags):
    tag_labels_dict[some_tag]=tag_id
    tag_names.append(some_tag)

tag_labels = [tag_labels_dict[post_label] for post_label in tags]

# %%
posts_table
# Out:
#        row_id       id                                            subject  \
# 0           0  1416971  Anyone receive an acceptep from IRS 2011 tax y...
# 1           1  1538913  Can everyone please post Time and Date- Filed,...
# 2           3  1691823  has anyone else received letter 4883c from irs...
# 3           6  1282342                                 Claim as dependant
# 4           7  1434355                 Anybody else still have March 1st?
# 5           8  1286252  Form 5405- First-Time Homebuyer Credit Repayme...
# 6          11  1701073                                    FRUSTRATED 8863
# 7          12  1438791              can the e-filing pin be sent to email
# 8          13  1271376  I signed in for the free edition for federal f...
# 9          16  1206139  Can I claim someone who has lived with me for ...
# 10         17  1157490  Now it is 2/15 has anyone had their return acc...
# 11         18  1258289  I rolled over a 401k into a traditional IRA. I...
# 12         20  1166908  I check the irs website and it says that i wil...
# 13         21  1741594  Has anyone who has gotten the IRS 4883C letter...
# 14         23  1383555  For those of you that ITEMIZED, but went ahead...
# 15         24  1705610  I haven't received my federal income tax refun...
# 16         26  1687551                 2/14 (or later) Acceptance w/ 8863
# 17         27  1378825   if i file on the 14th when should i get my money
# 18         28  1383549  Why doesn't the Basic Turbotax program let a S...
# 19         29  1696481                                 Form 8863 question
# 20         31  1706466  8863 :( can i have positive news from others w...
# 21         32  1196471   Why is Head of Household not showing as a choice
# 22         33  1681509  Has anyone who filed for the higher education ...
# 23         35  1162210  I have a new PIN, but it keeps saying it can't...
# 24         38  1178122  I went to IRS site and found form 8839, but I ...
# 25         39  1466445         in box 7 only # 7 is shown . how to enter?
# 26         40  1272168  federal return rejected cause they say someone...
# 27         41  1345142                            Return still in pending
# 28         42  1748167  For people with a DDD (send date) of March 6th...
# 29         44  1353386  Roll call for the 1/31 still processing crew a...
# ...       ...      ...                                                ...
# 19882   37227  1211903  We helped a friend buy a house and he already ...
# 19883   37228  1277695  i clicked the pay method to quick before i rea...
# 19884   37229  1408767                             Can I back file 1098t?
# 19885   37233  1806591  I paid a contractor for improvements made in m...
# 19886   37234  1151743  we can only take my son as a dependent and his...
# 19887   37235  1414399  i am filing a injured spouse return my husband...
# 19888   37236  1218047  How do I file my home that was rented part of ...
# 19889   37237  1808639  can I deduct health insurance premiums Ipaid i...
# 19890   37239  1155583  What if I did consulting work until April and ...
# 19891   37240  1221375  will my payment be late if I efiled on 4/18/11...
# 19892   37241  1156095  My daughter is away at college on a scholarshi...
# 19893   37242  1157119  I received 99 shares in a spin off which I sol...
# 19894   37243  1419519  Traditional IRA converted to Roth IRA (both in...
# 19895   37245  1354751  I started using my personal vehicle for 100 pe...
# 19896   37248  1355775  can I change where my refund goes after the ir...
# 19897   37249  1422335  I rolled over my entire 401k with the after-ta...
# 19898   37250  1292799       how do i know state and local sales tax rate
# 19899   37251  1163007  how is information transmitted during e-file. ...
# 19900   37254  1887999  How do I transfer a tax return from one comput...
# 19901   37255  1299711     Can I include a computer in business supplies?
# 19902   37256  1430783  can i file headhold if the person i take care ...
# 19903   37258  1366015  I'm active military, why am i still being char...
# 19904   37260  1170175  I waited the last day to file my income tax re...
# 19905   37262  1235967                  can i claim myself as a dependent
# 19906   37263  1434623  I have court papers saying that I can claim on...
# 19907   37267  1240319                          Years to fully depreciate
# 19908   37268  1371391  Depreciation and Amortization Report does not ...
# 19909   37269  1372415                                spouse died in 2008
# 19910   37273  1439487  What is number 5 in the federal return, I am a...
# 19911   37275  1376255  I would like to know if the IRS actually depos...
#
#            cached_question_tag_list
# 0                 electronic filing
# 1                 electronic filing
# 2                               irs
# 3                        dependents
# 4                 electronic filing
# 5                 electronic filing
# 6                               irs
# 7                 electronic filing
# 8                 electronic filing
# 9                        dependents
# 10                electronic filing
# 11                       retirement
# 12                electronic filing
# 13                              irs
# 14                electronic filing
# 15                          credits
# 16                          credits
# 17                electronic filing
# 18                          credits
# 19                              irs
# 20                       dependents
# 21                       dependents
# 22                          credits
# 23                electronic filing
# 24                electronic filing
# 25                       retirement
# 26                electronic filing
# 27                electronic filing
# 28                              irs
# 29                electronic filing
# ...                             ...
# 19882                    dependents
# 19883             electronic filing
# 19884            education expenses
# 19885                       credits
# 19886                    dependents
# 19887                    dependents
# 19888                   investments
# 19889                       credits
# 19890  self-employment (schedule c)
# 19891                         print
# 19892                    dependents
# 19893                   investments
# 19894                    retirement
# 19895  self-employment (schedule c)
# 19896             electronic filing
# 19897             electronic filing
# 19898             electronic filing
# 19899             electronic filing
# 19900             electronic filing
# 19901  self-employment (schedule c)
# 19902                    dependents
# 19903             electronic filing
# 19904             electronic filing
# 19905                    dependents
# 19906                    dependents
# 19907                   investments
# 19908                   investments
# 19909                    retirement
# 19910             electronic filing
# 19911                       credits
#
# [19912 rows x 4 columns]

# %% [markdown]
# # Split LC Questions into Training and Testing sets

# %%
post_subjects = posts_table[['subject']]
post_subjects
# Out:
#                                                  subject
# 0      Anyone receive an acceptep from IRS 2011 tax y...
# 1      Can everyone please post Time and Date- Filed,...
# 2      has anyone else received letter 4883c from irs...
# 3                                     Claim as dependant
# 4                     Anybody else still have March 1st?
# 5      Form 5405- First-Time Homebuyer Credit Repayme...
# 6                                        FRUSTRATED 8863
# 7                  can the e-filing pin be sent to email
# 8      I signed in for the free edition for federal f...
# 9      Can I claim someone who has lived with me for ...
# 10     Now it is 2/15 has anyone had their return acc...
# 11     I rolled over a 401k into a traditional IRA. I...
# 12     I check the irs website and it says that i wil...
# 13     Has anyone who has gotten the IRS 4883C letter...
# 14     For those of you that ITEMIZED, but went ahead...
# 15     I haven't received my federal income tax refun...
# 16                    2/14 (or later) Acceptance w/ 8863
# 17      if i file on the 14th when should i get my money
# 18     Why doesn't the Basic Turbotax program let a S...
# 19                                    Form 8863 question
# 20     8863 :( can i have positive news from others w...
# 21      Why is Head of Household not showing as a choice
# 22     Has anyone who filed for the higher education ...
# 23     I have a new PIN, but it keeps saying it can't...
# 24     I went to IRS site and found form 8839, but I ...
# 25            in box 7 only # 7 is shown . how to enter?
# 26     federal return rejected cause they say someone...
# 27                               Return still in pending
# 28     For people with a DDD (send date) of March 6th...
# 29     Roll call for the 1/31 still processing crew a...
# ...                                                  ...
# 19882  We helped a friend buy a house and he already ...
# 19883  i clicked the pay method to quick before i rea...
# 19884                             Can I back file 1098t?
# 19885  I paid a contractor for improvements made in m...
# 19886  we can only take my son as a dependent and his...
# 19887  i am filing a injured spouse return my husband...
# 19888  How do I file my home that was rented part of ...
# 19889  can I deduct health insurance premiums Ipaid i...
# 19890  What if I did consulting work until April and ...
# 19891  will my payment be late if I efiled on 4/18/11...
# 19892  My daughter is away at college on a scholarshi...
# 19893  I received 99 shares in a spin off which I sol...
# 19894  Traditional IRA converted to Roth IRA (both in...
# 19895  I started using my personal vehicle for 100 pe...
# 19896  can I change where my refund goes after the ir...
# 19897  I rolled over my entire 401k with the after-ta...
# 19898       how do i know state and local sales tax rate
# 19899  how is information transmitted during e-file. ...
# 19900  How do I transfer a tax return from one comput...
# 19901     Can I include a computer in business supplies?
# 19902  can i file headhold if the person i take care ...
# 19903  I'm active military, why am i still being char...
# 19904  I waited the last day to file my income tax re...
# 19905                  can i claim myself as a dependent
# 19906  I have court papers saying that I can claim on...
# 19907                          Years to fully depreciate
# 19908  Depreciation and Amortization Report does not ...
# 19909                                spouse died in 2008
# 19910  What is number 5 in the federal return, I am a...
# 19911  I would like to know if the IRS actually depos...
#
# [19912 rows x 1 columns]

# %%
subjects = np.array(post_subjects).ravel()
subjects
# Out:
# array(['Anyone receive an acceptep from IRS 2011 tax year?',
#        'Can everyone please post Time and Date- Filed, Accepted/Rejected, Date of Pay, ANY States POST Which States Please!',
#        'has anyone else received letter 4883c from irs?? if so how long did if take to get your money afterward??',
#        ..., 'spouse died in 2008',
#        "What is number 5 in the federal return, I am already claimed as a dependent by my parents shouldn't this be zero",
#        'I would like to know if the IRS actually deposited refunds on 1/25/2012? I still have nothing in my account.'], dtype=object)

# %%
subjects_train, subjects_test, tag_labels_train, tag_labels_test = train_test_split(
   subjects, tag_labels, test_size=0.25)

# %% [markdown]
# # Extracting features from the LiveCommunity Questions

# %%
print ("Extracting features from the LiveCommunity Questions")
# vectorizer = TfidfVectorizer(max_df=0.99, min_df=2,  ngram_range=(1, 1),
#                              stop_words='english')
vectorizer = CountVectorizer(max_df=0.99, min_df=2,  ngram_range=(1, 1)
                             )
X_train = vectorizer.fit_transform(subjects_train)
X_test = vectorizer.transform(subjects_test)

feature_names = vectorizer.get_feature_names()
n_samples, n_features = X_train.shape



# the label to predict is the id of tag
y_train = tag_labels_train
y_test = tag_labels_test
target_names = tag_names
n_classes = len(tag_names)

print("Total Training dataset size:")
print("n_samples: %d" % n_samples)
print("n_features: %d" % n_features)
print("n_classes: %d" % n_classes)
# Out:
# Extracting features from the LiveCommunity Questions
# Total Training dataset size:
# n_samples: 14934
# n_features: 4211
# n_classes: 10

# %%
feature_names
# Out:
# [u'00',
#  u'000',
#  u'0000',
#  u'0010',
#  u'0034',
#  u'01',
#  u'0151',
#  u'0156',
#  u'02',
#  u'0239',
#  u'0245',
#  u'025',
#  u'0296',
#  u'03',
#  u'04',
#  u'05',
#  u'06',
#  u'0679',
#  u'07',
#  u'08',
#  u'09',
#  u'0n',
#  u'10',
#  u'100',
#  u'1000',
#  u'10000',
#  u'1009',
#  u'100k',
#  u'1031',
#  u'104',
#  u'1040',
#  u'1040a',
#  u'1040es',
#  u'1040ez',
#  u'1040v',
#  u'1040x',
#  u'1041',
#  u'1042',
#  u'1045',
#  u'106',
#  u'1065',
#  u'109',
#  u'1096',
#  u'1098',
#  u'1098t',
#  u'1099',
#  u'1099_misc',
#  u'1099_r',
#  u'1099a',
#  u'1099b',
#  u'1099c',
#  u'1099g',
#  u'1099k',
#  u'1099misc',
#  u'1099q',
#  u'1099r',
#  u'1099rs',
#  u'1099s',
#  u'10k',
#  u'10th',
#  u'11',
#  u'110',
#  u'1100',
#  u'11000',
#  u'110000',
#  u'110k',
#  u'111',
#  u'1116',
#  u'1120',
#  u'1120s',
#  u'1127',
#  u'115',
#  u'119',
#  u'11k',
#  u'11th',
#  u'12',
#  u'120',
#  u'1200',
#  u'12000',
#  u'1201',
#  u'123',
#  u'1256',
#  u'12a',
#  u'13',
#  u'13000',
#  u'1301',
#  u'135',
#  u'139',
#  u'13th',
#  u'14',
#  u'1400',
#  u'14th',
#  u'15',
#  u'150',
#  u'1500',
#  u'15000',
#  u'150k',
#  u'154',
#  u'15a',
#  u'15b',
#  u'15k',
#  u'15th',
#  u'16',
#  u'1600',
#  u'166',
#  u'16a',
#  u'16b',
#  u'16k',
#  u'16th',
#  u'17',
#  u'179',
#  u'17th',
#  u'18',
#  u'1800',
#  u'186',
#  u'18th',
#  u'19',
#  u'1900',
#  u'197',
#  u'1995',
#  u'1997',
#  u'1998',
#  u'1999',
#  u'19th',
#  u'19yr',
#  u'1a',
#  u'1b',
#  u'1c',
#  u'1st',
#  u'20',
#  u'200',
#  u'2000',
#  u'2001',
#  u'2002',
#  u'2003',
#  u'2004',
#  u'2005',
#  u'2006',
#  u'2007',
#  u'2008',
#  u'2009',
#  u'2010',
#  u'2011',
#  u'2012',
#  u'2013',
#  u'2014',
#  u'20b',
#  u'20k',
#  u'20th',
#  u'21',
#  u'2106',
#  u'2106ez',
#  u'2137',
#  u'21st',
#  u'22',
#  u'2200',
#  u'2210',
#  u'224',
#  u'2250',
#  u'22nd',
#  u'23',
#  u'2300',
#  u'23rd',
#  u'24',
#  u'2400',
#  u'2441',
#  u'24th',
#  u'25',
#  u'250',
#  u'2500',
#  u'2555',
#  u'25k',
#  u'25th',
#  u'26',
#  u'26k',
#  u'26th',
#  u'27',
#  u'27th',
#  u'28',
#  u'2800',
#  u'288',
#  u'28th',
#  u'29',
#  u'296',
#  u'29th',
#  u'2a',
#  u'2b',
#  u'2c',
#  u'2k',
#  u'2nd',
#  u'2s',
#  u'30',
#  u'300',
#  u'3000',
#  u'30k',
#  u'30th',
#  u'31',
#  u'310',
#  u'3100',
#  u'315',
#  u'31st',
#  u'32',
#  u'32a',
#  u'33',
#  u'34',
#  u'340',
#  u'3400',
#  u'35',
#  u'350',
#  u'3500',
#  u'35k',
#  u'36',
#  u'365',
#  u'3650',
#  u'369',
#  u'37',
#  u'3700',
#  u'3800',
#  u'39',
#  u'3900',
#  u'3922',
#  u'3k',
#  u'3rd',
#  u'3x',
#  u'40',
#  u'400',
#  u'4000',
#  u'401',
#  u'401k',
#  u'402',
#  u'403',
#  u'403b',
#  u'41',
#  u'410',
#  u'4100',
#  u'41k',
#  u'42',
#  u'43',
#  u'43000',
#  u'44',
#  u'440',
#  u'443',
#  u'4464c',
#  u'45',
#  u'450',
#  u'4500',
#  u'4562',
#  u'457',
#  u'457b',
#  u'464',
#  u'465',
#  u'466',
#  u'4684',
#  u'47',
#  u'475',
#  u'4797',
#  u'48',
#  u'4852',
#  u'4868',
#  u'4883c',
#  u'49',
#  u'492',
#  u'496',
#  u'4k',
#  u'4th',
#  u'4yrs',
#  u'50',
#  u'500',
#  u'5000',
#  u'501',
#  u'5071c',
#  u'50k',
#  u'512',
#  u'52',
#  u'5200',
#  u'523',
#  u'527',
#  u'529',
#  u'53',
#  u'5329',
#  u'53a',
#  u'53c',
#  u'54',
#  u'5404',
#  u'5405',
#  u'5498',
#  u'55',
#  u'55000',
#  u'56',
#  u'5600',
#  u'5695',
#  u'57',
#  u'575',
#  u'578',
#  u'58',
#  u'5800',
#  u'59',
#  u'5k',
#  u'5th',
#  u'60',
#  u'600',
#  u'6000',
#  u'61',
#  u'611',
#  u'62',
#  u'620',
#  u'63',
#  u'64',
#  u'65',
#  u'650',
#  u'6500',
#  u'66',
#  u'666',
#  u'668',
#  u'67',
#  u'6700',
#  u'674',
#  u'68',
#  u'69',
#  u'6a',
#  u'6b',
#  u'6c',
#  u'6k',
#  u'6th',
#  u'70',
#  u'700',
#  u'7000',
#  u'701',
#  u'71',
#  u'712',
#  u'72',
#  u'7200',
#  u'74',
#  u'75',
#  u'750',
#  u'751',
#  u'753',
#  u'76',
#  u'79',
#  u'7k',
#  u'7th',
#  u'80',
#  u'800',
#  u'8000',
#  u'827',
#  u'8283',
#  u'83',
#  u'8332',
#  u'8379',
#  u'8396',
#  u'84',
#  u'8453',
#  u'85',
#  u'8582',
#  u'86',
#  u'8606',
#  u'87',
#  u'8812',
#  u'8814',
#  u'8815',
#  u'8824',
#  u'8829',
#  u'8839',
#  u'886',
#  u'8862',
#  u'8863',
#  u'8880',
#  u'8888',
#  u'89',
#  u'8910',
#  u'8936',
#  u'8949',
#  u'8th',
#  u'90',
#  u'900',
#  u'9000',
#  u'902',
#  u'904',
#  u'91',
#  u'92',
#  u'93',
#  u'941',
#  u'946',
#  u'9465',
#  u'95',
#  u'950',
#  u'9500',
#  u'96',
#  u'9600',
#  u'97',
#  u'98',
#  u'982',
#  u'99',
#  u'990',
#  u'9b',
#  u'9k',
#  u'9th',
#  u'abandoned',
#  u'able',
#  u'about',
#  u'above',
#  u'abroad',
#  u'absurd',
#  u'academy',
#  u'accept',
#  u'acceptable',
#  u'acceptance',
#  u'accepted',
#  u'accepting',
#  u'accepts',
#  u'access',
#  u'accident',
#  u'accidentally',
#  u'accidently',
#  u'accnt',
#  u'according',
#  u'account',
#  u'accountant',
#  u'accounted',
#  u'accounting',
#  u'accounts',
#  u'accout',
#  u'accpeted',
#  u'accrual',
#  u'accrued',
#  u'acct',
#  u'accumulated',
#  u'accurate',
#  u'accurately',
#  u'acess',
#  u'acknowledge',
#  u'acknowledged',
#  u'acknowledgment',
#  u'acquired',
#  u'acquisition',
#  u'acres',
#  u'across',
#  u'act',
#  u'acting',
#  u'action',
#  u'active',
#  u'actively',
#  u'activities',
#  u'activity',
#  u'acts',
#  u'actual',
#  u'actually',
#  u'add',
#  u'added',
#  u'adding',
#  u'addition',
#  u'additional',
#  u'additions',
#  u'address',
#  u'adds',
#  u'adequate',
#  u'adjust',
#  u'adjusted',
#  u'adjustment',
#  u'adjustments',
#  u'admend',
#  u'admin',
#  u'adobe',
#  u'adopt',
#  u'adopted',
#  u'adopting',
#  u'adoption',
#  u'adp',
#  u'adult',
#  u'advance',
#  u'advantage',
#  u'advertise',
#  u'advertised',
#  u'advertises',
#  u'advertising',
#  u'advice',
#  u'advise',
#  u'advised',
#  u'advisor',
#  u'advocate',
#  u'affect',
#  u'affected',
#  u'affecting',
#  u'afford',
#  u'afghanistan',
#  u'after',
#  u'again',
#  u'against',
#  u'age',
#  u'agency',
#  u'agent',
#  u'ages',
#  u'agi',
#  u'ago',
#  u'agree',
#  u'agreed',
#  u'agreement',
#  u'ahead',
#  u'aid',
#  u'aig',
#  u'air',
#  u'airbnb',
#  u'alabama',
#  u'alien',
#  u'alimony',
#  u'all',
#  u'allocate',
#  u'allocating',
#  u'allocation',
#  u'allow',
#  u'allowable',
#  u'allowance',
#  u'allowances',
#  u'allowed',
#  u'allowing',
#  u'allows',
#  u'allready',
#  u'almost',
#  u'alone',
#  u'along',
#  u'alot',
#  u'already',
#  u'also',
#  u'alternate',
#  u'alternative',
#  u'alternatives',
#  u'although',
#  u'always',
#  u'am',
#  u'ameded',
#  u'amend',
#  u'amended',
#  u'amending',
#  u'amendment',
#  u'amendments',
#  u'america',
#  u'american',
#  u'ameritrade',
#  u'ammend',
#  u'ammended',
#  u'ammendment',
#  u'amortization',
#  u'amortized',
#  u'amortizing',
#  u'amount',
#  u'amounts',
#  u'amout',
#  u'amt',
#  u'an',
#  u'and',
#  u'animals',
#  u'announced',
#  u'annual',
#  u'annuity',
#  u'another',
#  u'answer',
#  u'answered',
#  u'answering',
#  u'answers',
#  u'anthing',
#  u'anticipate',
#  u'any',
#  u'anybody',
#  u'anymore',
#  u'anyone',
#  u'anything',
#  u'anyway',
#  u'anywhere',
#  u'aoc',
#  u'apart',
#  u'apartment',
#  u'apartments',
#  u'app',
#  u'apparently',
#  u'appartment',
#  u'appear',
#  u'appeared',
#  u'appearing',
#  u'appears',
#  u'appliance',
#  u'appliances',
#  u'applicable',
#  u'application',
#  u'applied',
#  u'applies',
#  u'apply',
#  u'applying',
#  u'appointments',
#  u'appraisal',
#  u'appreciated',
#  u'appropriate',
#  u'approved',
#  u'approx',
#  u'approximately',
#  u'appx',
#  u'apr',
#  u'april',
#  u'apt',
#  u'aquired',
#  u'ar',
#  u'are',
#  u'area',
#  u'areas',
#  u'aren',
#  u'arent',
#  u'arizona',
#  u'arkansas',
#  u'army',
#  u'around',
#  u'arrangements',
#  u'arrested',
#  u'arrive',
#  u'arrived',
#  u'art',
#  u'artist',
#  u'as',
#  u'asap',
#  u'aside',
#  u'ask',
#  u'asked',
#  u'asking',
#  u'asks',
#  u'aspergers',
#  u'assessed',
#  u'assessment',
#  u'asset',
#  u'assets',
#  u'assigned',
#  u'assignment',
#  u'assistance',
#  u'assistant',
#  u'assisted',
#  u'associated',
#  u'association',
#  u'assume',
#  u'assuming',
#  u'assure',
#  u'assured',
#  u'at',
#  u'atlanta',
#  u'atm',
#  u'attach',
#  u'attached',
#  u'attaching',
#  u'attempt',
#  u'attempted',
#  u'attempting',
#  u'attend',
#  u'attended',
#  u'attending',
#  u'attends',
#  u'attic',
#  u'attorney',
#  u'auction',
#  u'audit',
#  u'audited',
#  u'aug',
#  u'august',
#  u'aunt',
#  u'austin',
#  u'authentication',
#  u'authority',
#  u'authorized',
#  u'autism',
#  u'autistic',
#  u'auto',
#  u'automated',
#  u'automatic',
#  u'automatically',
#  u'available',
#  u'average',
#  u'averaging',
#  u'avoid',
#  u'avon',
#  u'award',
#  u'awarded',
#  u'awards',
#  u'aware',
#  u'away',
#  u'az',
#  u'baby',
#  u'babys',
#  u'babysit',
#  u'babysitter',
#  u'babysitting',
#  u'back',
#  u'background',
#  u'backpay',
#  u'backup',
#  u'backyard',
#  u'bad',
#  u'bags',
#  u'balance',
#  u'balances',
#  u'bank',
#  u'banking',
#  u'bankrupt',
#  u'bankruptcy',
#  u'banks',
#  u'bar',
#  u'barbara',
#  u'barely',
#  u'barrel',
#  u'bars',
#  u'barter',
#  u'base',
#  u'based',
#  u'basement',
#  u'basic',
#  u'basically',
#  u'basis',
#  u'bathroom',
#  u'bc',
#  u'be',
#  u'became',
#  u'because',
#  u'become',
#  u'becomes',
#  u'becuase',
#  u'bed',
#  u'bedroom',
#  u'been',
#  u'before',
#  u'began',
#  u'begin',
#  u'begining',
#  u'beginning',
#  u'begins',
#  u'behalf',
#  u'behind',
#  u'being',
#  u'believe',
#  u'belive',
#  u'belong',
#  u'below',
#  u'beneficial',
#  u'beneficiary',
#  u'benefit',
#  u'benefits',
#  u'benifits',
#  u'besides',
#  u'best',
#  u'better',
#  u'between',
#  u'beware',
#  u'beyond',
#  u'bf',
#  u'big',
#  u'biggest',
#  u'bill',
#  u'billed',
#  u'billing',
#  u'bills',
#  u'biological',
#  u'birth',
#  u'birthdate',
#  u'birthday',
#  u'bit',
#  u'biz',
#  u'bk',
#  u'blank',
#  u'blanks',
#  u'blind',
#  u'blinds',
#  u'block',
#  u'blood',
#  u'board',
#  u'boarding',
#  u'boat',
#  u'bond',
#  u'bonds',
#  u'bonus',
#  u'bonuses',
#  u'book',
#  u'books',
#  u'booth',
#  u'born',
#  u'borrowed',
#  u'boss',
#  u'both',
#  u'bottom',
#  u'bough',
#  u'bought',
#  u'box',
#  u'box1',
#  u'boxes',
#  u'boy',
#  u'boyfriend',
#  u'boyfriends',
#  u'boys',
#  u'bracket',
#  u'brain',
#  u'break',
#  u'breakdown',
#  u'breaks',
#  u'bring',
#  u'bringing',
#  u'brings',
#  u'broke',
#  u'broken',
#  u'broker',
#  u'brokerage',
#  u'brother',
#  u'brothers',
#  u'brought',
#  u'bs',
#  u'btw',
#  u'bucks',
#  u'bug',
#  u'building',
#  u'buildings',
#  u'built',
#  u'buisness',
#  u'bull',
#  u'burden',
#  u'burning',
#  u'burst',
#  u'bus',
#  u'busines',
#  u'business',
#  u'businesses',
#  u'bussiness',
#  u'but',
#  u'button',
#  u'buttons',
#  u'buy',
#  u'buyer',
#  u'buyers',
#  u'buying',
#  u'buys',
#  u'by',
#  u'bypass',
#  u'ca',
#  u'cabin',
#  u'cable',
#  u'cafeteria',
#  u'cal',
#  u'calc',
#  u'calculate',
#  u'calculated',
#  u'calculates',
#  u'calculating',
#  u'calculation',
#  u'calculations',
#  u'calendar',
#  u'california',
#  u'calim',
#  u'calimed',
#  u'call',
#  u'called',
#  u'calling',
#  u'calls',
#  u'came',
#  u'campus',
#  u'can',
#  u'canada',
#  u'canadian',
#  u'cancel',
#  u'cancellation',
#  u'cancelled',
#  u'cancer',
#  u'cannont',
#  u'cannot',
#  u'cant',
#  u'cap',
#  u'capital',
#  u'capitol',
#  u'captial',
#  u'car',
#  u'card',
#  u'cards',
#  u'care',
#  u'cared',
#  u'careful',
#  u'caregiver',
#  u'caring',
#  u'carolina',
#  u'carried',
#  u'carrier',
#  u'carries',
#  u'carry',
#  u'carryforward',
#  u'carrying',
#  u'carryover',
#  u'carryovers',
#  u'caryover',
#  u'case',
#  u'cash',
#  u'cashed',
#  u'cashing',
#  u'casino',
#  u'catagory',
#  u'catch',
#  u'categories',
#  u'category',
#  u'catholic',
#  u'cattle',
#  u'cause',
#  u'caused',
#  u'causes',
#  u'causing',
#  u'cc',
#  u'cd',
#  u'cell',
#  u'cement',
#  u'center',
#  u'central',
#  u'cents',
#  u'certain',
#  u'certificate',
#  u'certificates',
#  u'chaged',
#  u'challenged',
#  u'chance',
#  u'change',
#  u'changed',
#  u'changes',
#  u'changing',
#  u'chapter',
#  u'characters',
#  u'charge',
#  u'charged',
#  u'charges',
#  u'charging',
#  u'charitable',
#  u'charities',
#  u'charity',
#  u'charles',
#  u'chart',
#  u'chat',
#  u'cheaper',
#  u'check',
#  u'checkbox',
#  u'checked',
#  u'checking',
#  u'checks',
#  u'chged',
#  u'chidlren',
#  u'child',
#  u'childcare',
#  u'childred',
#  u'children',
#  u'childrens',
#  u'childs',
#  u'childsupport',
#  u'chilren',
#  u'choice',
#  u'choose',
#  u'choosing',
#  u'chose',
#  u'chosen',
#  u'christmas',
#  u'church',
#  u'circle',
#  u'circumstances',
#  u'citizen',
#  u'citizens',
#  u'citizenship',
#  u'city',
#  u'civil',
#  u'claim',
#  u'claimed',
#  u'claiming',
#  u'claims',
#  u'clain',
#  u'clam',
#  u'clame',
#  u'claming',
#  u'clarification',
#  u'clarify',
#  u'class',
#  u'classes',
#  u'classify',
#  u'clean',
#  u'cleaning',
#  u'clear',
#  u'cleared',
#  u'clearly',
#  u'clergy',
#  u'click',
#  u'clicked',
#  u'client',
#  u'clients',
#  u'close',
#  u'closed',
#  u'closing',
#  u'clothes',
#  u'clothing',
#  u'club',
#  u'clue',
#  u'clueless',
#  u'co',
#  u'cobra',
#  u'code',
#  u'codes',
#  u'cogs',
#  u'collage',
#  u'collect',
#  u'collected',
#  u'collecting',
#  ...]

# %% [markdown]
# # Train Support Vector Machine (SVM) Classifier

# %%
###############################################################################
# Train a SVM classification model

clf = LinearSVC(penalty="l1", dual=False, tol=1e-3, C=0.1)
clf = clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %% [markdown]
# # Qualitative Evaluation of the Predictions

# %%
def show_examples(num_questions, y_test, y_pred, target_names):
    for ind_ques in range(num_questions):
        this_match='-'
        if y_test[ind_ques]==y_pred[ind_ques]:
            this_match='+'
        print('\n'*2)
        print('='*80)

        print('{:<13} {}'.format('LiveCommunity Question:',this_match*40))
        print()
        print(subjects_test[ind_ques])
        print('{:<13}:{}'.format('Predicted Tag',target_names[y_pred[ind_ques]]))
        print('{:<13}:{}'.format('True Tag',target_names[y_test[ind_ques]]))

# %%
num_questions=20
show_examples(num_questions, y_test, y_pred, target_names)
# Out:
# ================================================================================
# LiveCommunity Question: ++++++++++++++++++++++++++++++++++++++++
#
# Why is my daughter shown as “Not A Dependent" this year?
# Predicted Tag:dependents
# True Tag     :dependents
#
#
#
# ================================================================================
# LiveCommunity Question: ++++++++++++++++++++++++++++++++++++++++
#
# If I am in the military stationed in California is it considered income received in a state other than home of record?
# Predicted Tag:dependents
# True Tag     :dependents
#
#
#
# ================================================================================
# LiveCommunity Question: ----------------------------------------
#
# Who gets the tax refund?  The LLC or the owner?
# Predicted Tag:electronic filing
# True Tag     :self-employment (schedule c)
#
#
#
# ================================================================================
# LiveCommunity Question: ----------------------------------------
#
# I have a loss on my residential rental property. After entering all the figures, Turbo Tax shows no loss, or gain. What's happening?
# Predicted Tag:investments
# True Tag     :business
#
#
#
# ================================================================================
# LiveCommunity Question: ----------------------------------------
#
# what do I do if I had several differrent businesses and some didn't have 1099s?
# Predicted Tag:electronic filing
# True Tag     :self-employment (schedule c)
#
#
#
# ================================================================================
# LiveCommunity Question: ++++++++++++++++++++++++++++++++++++++++
#
# Why does my state refund state "process and check had been written" when I requested direct deposit the same as on my federal taxes
# Predicted Tag:electronic filing
# True Tag     :electronic filing
#
#
#
# ================================================================================
# LiveCommunity Question: ++++++++++++++++++++++++++++++++++++++++
#
# I rolled over a pension and a 401k into a traditional IRA, I click "no" for all questions pertaining to ROTH IRA conversion, why does Turbotax still want me to claim the whole amount as a conversion to a ROTH IRA?????
# Predicted Tag:retirement
# True Tag     :retirement
#
#
#
# ================================================================================
# LiveCommunity Question: ++++++++++++++++++++++++++++++++++++++++
#
# Can TTax handle wash sale with RSUs ?
# Predicted Tag:investments
# True Tag     :investments
#
#
#
# ================================================================================
# LiveCommunity Question: ----------------------------------------
#
# can I save what i've done? I have another income statement coming yet
# Predicted Tag:dependents
# True Tag     :electronic filing
#
#
#
# ================================================================================
# LiveCommunity Question: ++++++++++++++++++++++++++++++++++++++++
#
# i already filed one tax return. can i file my other tax return but its from a different company
# Predicted Tag:electronic filing
# True Tag     :electronic filing
#
#
#
# ================================================================================
# LiveCommunity Question: ++++++++++++++++++++++++++++++++++++++++
#
# I have not lived with my spouse this year
# Predicted Tag:dependents
# True Tag     :dependents
#
#
#
# ================================================================================
# LiveCommunity Question: ++++++++++++++++++++++++++++++++++++++++
#
# Minnesota - mail check but use credit card instead??
# Predicted Tag:electronic filing
# True Tag     :electronic filing
#
#
#
# ================================================================================
# LiveCommunity Question: ++++++++++++++++++++++++++++++++++++++++
#
# Can you claim a deceased parent if they only lived 4 months of the year
# Predicted Tag:dependents
# True Tag     :dependents
#
#
#
# ================================================================================
# LiveCommunity Question: ++++++++++++++++++++++++++++++++++++++++
#
# I Lived apart from my husband but want to claim as a household. Is my husband can file his return tax on his own?
# Predicted Tag:dependents
# True Tag     :dependents
#
#
#
# ================================================================================
# LiveCommunity Question: ++++++++++++++++++++++++++++++++++++++++
#
# Why is our rental's depreciation limited to the difference bewteen rental expense and rental income?
# Predicted Tag:investments
# True Tag     :investments
#
#
#
# ================================================================================
# LiveCommunity Question: ++++++++++++++++++++++++++++++++++++++++
#
# i need to get a copy of my 2010 returns but no programs on my computer can download it
# Predicted Tag:dependents
# True Tag     :dependents
#
#
#
# ================================================================================
# LiveCommunity Question: ++++++++++++++++++++++++++++++++++++++++
#
# i put resident on my turbo tax i meant to put alien how do i change it?
# Predicted Tag:dependents
# True Tag     :dependents
#
#
#
# ================================================================================
# LiveCommunity Question: ++++++++++++++++++++++++++++++++++++++++
#
# My broker sells $35 worth of my 10 yr old stock each year to cover maintenance fees. Is this a long term or short term gain or loss? I have not purchased stock, but have received dividends.
# Predicted Tag:investments
# True Tag     :investments
#
#
#
# ================================================================================
# LiveCommunity Question: ++++++++++++++++++++++++++++++++++++++++
#
# why can i not deduct the 36.95 out of my state return
# Predicted Tag:electronic filing
# True Tag     :electronic filing
#
#
#
# ================================================================================
# LiveCommunity Question: ----------------------------------------
#
# WHY?...........
# Predicted Tag:electronic filing
# True Tag     :education expenses

# %% [markdown]
# # Quantitative evaluation of the model quality on the test set

# %%
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                               precision    recall  f1-score   support
#
#                   retirement       0.74      0.79      0.76       362
#                     business       0.74      0.08      0.14       180
#            electronic filing       0.64      0.82      0.72      1241
#                          irs       0.59      0.43      0.50       199
#                      credits       0.63      0.40      0.49       307
# self-employment (schedule c)       0.60      0.64      0.62       495
#           education expenses       0.78      0.66      0.72       187
#                        print       0.72      0.42      0.53       264
#                   dependents       0.72      0.77      0.75      1238
#                  investments       0.78      0.72      0.75       505
#
#                  avg / total       0.69      0.68      0.67      4978

# %% [markdown]
# # Visualize Indicative Class Features

# %%
weights = clf.coef_
frequencies=X_train.sum(axis=0).tolist()[0]
def get_indicative_features(feat_weights):
    ind_sorted_feature_weights = feat_weights.argsort()[::-1]
    indicative_feats = []
    for ind in ind_sorted_feature_weights:
        if abs(feat_weights[ind])<0.0001:
            break
        indicative_feats.append((feature_names[ind],frequencies[ind],feat_weights[ind]))
    return indicative_feats

class_and_indicative_feats = []       
for ind_class, class_name in enumerate(target_names):
    current_class_weigts = weights[ind_class]
    indicative_feats = get_indicative_features(current_class_weigts)
    class_and_indicative_feats.append((class_name,indicative_feats))

# %%
class_index = 2
class_name, feat_info = class_and_indicative_feats[class_index]

words = [(word, score) for word,score,_ in feat_info]
# Compute the position of the words.
wc = WordCloud(background_color="white", max_words=2000)
wc.fit_words(words)
# elements = wordcloud.fit_words(words, )
# Draw the positioned words to a PNG file.
wc.to_file('test.png')
print(class_name)
Image('test.png')
# Out:
# electronic filing

# %% [markdown]
# # Excercise

# %% [markdown]
# 1. Go to https://ttlc.intuit.com/tags
# 2. Click on a tag from one of these tags: Retirement, business, electronic
# filing, credits, self-employment (schedule c), education expenses, dependents, investments, print.
# 3. Click on any of the questions posted under this tag.
# 4. Use the Classifier we trained in this Live Community study to tag the question.
# Does the tag our classifier produced in one of the tags of the original questions?

# %%
#enter your question here
#some_question = ['Does my 401K contributions showing on my W2 qualify as a retirement contributions expense?']
